# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("/content/HousingData.csv")

# %% [markdown]
# CRIM: Crime Rate
#
#
# ZN: Residential Zoning
#
#
# INDUS: Industrial Proportion
#
#
# CHAS: Charles River Indicator
#
#
# NOX: Nitric Oxide Concentration
#
#
# RM: Rooms per Dwelling
#
#
# AGE: Proportion of Older Homes
#
#
# DIS: Distance to Employment Centers
#
#
# RAD: Accessibility to Radial Highways
#
#
# TAX: Property Tax Rate
#
#
# PTRATIO: Pupil-Teacher Ratio
#
#
# B: Demographic Indicator
#
#
# LSTAT: Lower-Status Population Percentage
#
#
# MEDV: Median Value of Homes

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO       B  LSTAT  MEDV
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7  396.90    NaN  36.2

# %%
df.shape
# Out:
# (506, 14)

# %%
df.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='mean')
df_imputed = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)

# %%
df_imputed.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
df = df_imputed
df.describe()
# Out:
#              CRIM          ZN       INDUS  ...           B       LSTAT        MEDV
# count  506.000000  506.000000  506.000000  ...  506.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992  ...  356.674032   12.715432   22.532806
# std      8.545770   22.921051    6.699165  ...   91.294864    7.012739    9.197104
# min      0.006320    0.000000    0.460000  ...    0.320000    1.730000    5.000000
# 25%      0.083235    0.000000    5.190000  ...  375.377500    7.230000   17.025000
# 50%      0.290250    0.000000    9.900000  ...  391.440000   11.995000   21.200000
# 75%      3.611874   11.211934   18.100000  ...  396.225000   16.570000   25.000000
# max     88.976200  100.000000   27.740000  ...  396.900000   37.970000   50.000000
#
# [8 rows x 14 columns]

# %%
df.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS  ...   PTRATIO         B     LSTAT      MEDV
# CRIM     1.000000 -0.182930  0.391161 -0.052223  ...  0.273384 -0.370163  0.434044 -0.379695
# ZN      -0.182930  1.000000 -0.513336 -0.036147  ... -0.403085  0.167431 -0.407549  0.365943
# INDUS    0.391161 -0.513336  1.000000  0.058035  ...  0.384806 -0.354597  0.567354 -0.478657
# CHAS    -0.052223 -0.036147  0.058035  1.000000  ... -0.109310  0.050055 -0.046166  0.179882
# NOX      0.410377 -0.502287  0.740965  0.073286  ...  0.188933 -0.380051  0.572379 -0.427321
# RM      -0.215434  0.316550 -0.381457  0.102284  ... -0.355501  0.128069 -0.602962  0.695360
# AGE      0.344934 -0.541274  0.614592  0.075206  ...  0.262723 -0.265282  0.574893 -0.380223
# DIS     -0.366523  0.638388 -0.699639 -0.091680  ... -0.232471  0.291512 -0.483429  0.249929
# RAD      0.608886 -0.306316  0.593176  0.001425  ...  0.464741 -0.444413  0.468440 -0.381626
# TAX      0.566528 -0.308334  0.716062 -0.031483  ...  0.460853 -0.441808  0.524545 -0.468536
# PTRATIO  0.273384 -0.403085  0.384806 -0.109310  ...  1.000000 -0.177383  0.373343 -0.507787
# B       -0.370163  0.167431 -0.354597  0.050055  ... -0.177383  1.000000 -0.368886  0.333461
# LSTAT    0.434044 -0.407549  0.567354 -0.046166  ...  0.373343 -0.368886  1.000000 -0.721975
# MEDV    -0.379695  0.365943 -0.478657  0.179882  ... -0.507787  0.333461 -0.721975  1.000000
#
# [14 rows x 14 columns]

# %%
plt.figure(figsize = (10, 10))
sns.heatmap(df.corr(), cbar = True, square = True, fmt = '.1f', annot = True, annot_kws = {'size' : 8}, cmap = 'Blues')
# Out:
# <Axes: >

# %%
X = df.drop(columns = 'MEDV', axis = 1)
y = df['MEDV']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 2)

# %%
model = XGBRegressor(n_estimators=1000, learning_rate=0.05)
model.fit(X_train, y_train)
model.predict(X_test)
# Out:
# array([21.078407 , 21.676619 , 29.843678 , 29.308004 ,  9.081558 ,
#        12.646635 , 28.428442 , 28.43322  , 18.85811  , 20.619543 ,
#        27.110931 , 25.143963 , 19.459133 , 21.502796 , 20.221407 ,
#        22.013018 , 19.328959 ,  9.373875 ,  9.433147 , 15.241745 ,
#        22.20389  , 21.078423 , 34.56687  , 18.590004 , 13.262878 ,
#        19.25294  , 45.926712 , 31.950878 , 33.863407 , 18.895132 ,
#        15.760176 , 19.531334 , 29.688793 , 24.18238  ,  7.4766884,
#        16.647318 ,  8.437815 , 21.568117 , 22.935421 , 21.874046 ,
#        26.23734  , 13.441925 , 27.776426 ,  7.559027 , 20.6075   ,
#        14.882748 , 34.943863 , 15.090968 , 31.591356 , 14.455308 ,
#        30.07142  , 27.335554 ,  6.340823 , 33.058174 , 20.060312 ,
#        20.02575  , 19.1474   , 20.758255 , 15.535575 , 21.080177 ,
#        19.893513 , 20.705318 , 17.670422 , 28.997293 , 33.68536  ,
#        25.24768  , 49.944836 , 29.783175 ,  8.702302 , 23.283682 ,
#        15.654156 ,  8.237304 , 15.409539 , 18.459387 , 26.945644 ,
#        23.48321  , 21.945105 , 21.627687 , 19.27036  , 23.888569 ,
#        34.183254 , 17.757406 , 19.802553 , 30.75296  , 34.98095  ,
#        33.437675 , 17.537937 , 24.82385  , 29.304941 , 20.066727 ,
#        20.1168   , 20.863388 , 11.287942 , 39.00905  , 43.395115 ,
#         9.1316185, 35.86407  , 34.235504 , 21.670433 , 15.843638 ,
#        27.7047   , 23.506657 ], dtype=float32)
